# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
dataList = []
for filename in os.listdir ("Daily Stock Price  Returns104600698"):
    if filename[-3:] == "csv":
        head = r"Daily Stock Price  Returns104600698/"
        data = pd.read_csv(head + filename, index_col=0)
        dataList.append(data)
for filename in os.listdir ("Daily Stock Price  Returns165304594"):
    if filename[-3:] == "csv":
        head = r"Daily Stock Price  Returns165304594/"
        data = pd.read_csv(head + filename, index_col=0)
        dataList.append(data)
data = pd.concat(dataList, axis = 0)

# %% [markdown]
# Stkcd [Stock Code] - Codes released by the Shanghai and Shenzhen Stock Exchanges\
# Trddt [Trading Date] - Denoted by YYYY-MM-DD\
# Dretwd [Daily Return With Cash Dividend Reinvested] - Issue price is used as previous closing price of a stock on its first trading day. Please refer to “How Returns Are Calculated”.\

# %%
data
# Out:
#              Trddt    Dretwd
# Stkcd
# 1       2013-01-04 -0.001873
# 1       2013-01-07  0.019387
# 1       2013-01-08 -0.018405
# 1       2013-01-09 -0.008750
# 1       2013-01-10  0.000631
# ...            ...       ...
# 900957  2022-12-26  0.021779
# 900957  2022-12-27  0.001776
# 900957  2022-12-28 -0.007092
# 900957  2022-12-29 -0.005357
# 900957  2022-12-30  0.012567
#
# [8210216 rows x 2 columns]

# %% [markdown]
# I use the index in eps to exclude the non-mainboard stocks.

# %%
eps_data = pd.read_csv("Processed_EPS.csv")

# %%
eps_data.Stkcd.unique
# Out:
# <bound method Series.unique of 0             1
# 1             1
# 2             1
# 3             1
# 4             1
#           ...
# 35182    605333
# 35183    605336
# 35184    605358
# 35185    605366
# 35186    605399
# Name: Stkcd, Length: 35187, dtype: int64>

# %%
data = data.loc[eps_data.Stkcd.unique()]

# %%
data
# Out:
#              Trddt    Dretwd
# Stkcd
# 1       2013-01-04 -0.001873
# 1       2013-01-07  0.019387
# 1       2013-01-08 -0.018405
# 1       2013-01-09 -0.008750
# 1       2013-01-10  0.000631
# ...            ...       ...
# 605399  2022-12-26  0.055997
# 605399  2022-12-27  0.008135
# 605399  2022-12-28 -0.019725
# 605399  2022-12-29 -0.008232
# 605399  2022-12-30 -0.007070
#
# [6022126 rows x 2 columns]

# %%
market_return = pd.read_csv("Aggregated Daily Market Returns204344531/TRD_Cndalym.csv", index_col=0)

# %%
market_return
# Out:
#                  Trddt  Cdretwdeq
# Markettype
# 10          2013-01-04   0.014720
# 5           2013-01-04  -0.003810
# 15          2013-01-04  -0.002974
# 21          2013-01-04  -0.002965
# 31          2013-01-04  -0.002279
# ...                ...        ...
# 95          2022-12-30   0.007401
# 101         2022-12-30   0.006584
# 111         2022-12-30   0.006558
# 117         2022-12-30   0.006544
# 127         2022-12-30   0.006525
#
# [46170 rows x 2 columns]

# %% [markdown]
# Markettype [Aggregated Market Type] - 5= SSE-SZSE A share market (excluding STAR Market, ChiNext); 10= SSE-SZSE B share market; 15= SSE-SZSE A & B share market; 21= SSE-SZSE A share market and ChiNext; 31= SSE-SZSE A & B share market and ChiNext; 37= SSE-SZSE A share market and STAR Market; 47= SSE-SZSE A & B share market and STAR Market; 53= SSE-SZSE A share market and ChiNext and STAR Market; 63= SSE-SZSE A & B share market and ChiNext and STAR Market; 33= SSE A share market and STAR Market; 20= SZSE A share market and ChiNext; 69= SSE-SZSE-BSE A share market; 79= SSE-SZSE-BSE A & B share market; 85= SSE-SZSE-BSE A share market and ChiNext; 95= SSE-SZSE-BSE A & B share market and ChiNext; 101= SSE-SZSE-BSE A share market and STAR Market; 111= SSE-SZSE-BSE A & B share market and STAR Market; 117= SSE-SZSE-BSE A share market and ChiNext and STAR Market; 127= SSE-SZSE-BSE A & B share market and ChiNext and STAR Market\
# Trddt [Trading Date] - Denoted by YYYY-MM-DD\
# Cdretwdos [Daily Aggregated Market Returns With Cash Dividend Reinvested (Current-Value-Weighted)] - Please refer to “How Returns Are Calculated”

# %%
market_return = market_return.loc[5]

# %%
market_return = market_return.set_index("Trddt")

# %%
data = data.reset_index()
data = data.set_index("Trddt")

# %%
data
# Out:
#              Stkcd    Dretwd
# Trddt
# 2013-01-04       1 -0.001873
# 2013-01-07       1  0.019387
# 2013-01-08       1 -0.018405
# 2013-01-09       1 -0.008750
# 2013-01-10       1  0.000631
# ...            ...       ...
# 2022-12-26  605399  0.055997
# 2022-12-27  605399  0.008135
# 2022-12-28  605399 -0.019725
# 2022-12-29  605399 -0.008232
# 2022-12-30  605399 -0.007070
#
# [6022126 rows x 2 columns]

# %%
 def merge_market(data: pd.DataFrame) -> pd.DataFrame:
    print(data.index[0])
    data.loc[:, "AR"] = data.loc[:, "Dretwd"] - market_return.loc[data.index[0]][0]
    data.to_csv(r"individual_stock_return/" + data.index[0])

# %%
new_data = data.groupby("Trddt").apply(merge_market)
# Out:
# 2013-01-04
# 2013-01-07
# 2013-01-08
# 2013-01-09
# 2013-01-10
# 2013-01-11
# 2013-01-14
# 2013-01-15
# 2013-01-16
# 2013-01-17
# 2013-01-18
# 2013-01-21
# 2013-01-22
# 2013-01-23
# 2013-01-24
# 2013-01-25
# 2013-01-28
# 2013-01-29
# 2013-01-30
# 2013-01-31
# 2013-02-01
# 2013-02-04
# 2013-02-05
# 2013-02-06
# 2013-02-07
# 2013-02-08
# 2013-02-18
# 2013-02-19
# 2013-02-20
# 2013-02-21
# 2013-02-22
# 2013-02-25
# 2013-02-26
# 2013-02-27
# 2013-02-28
# 2013-03-01
# 2013-03-04
# 2013-03-05
# 2013-03-06
# 2013-03-07
# 2013-03-08
# 2013-03-11
# 2013-03-12
# 2013-03-13
# 2013-03-14
# 2013-03-15
# 2013-03-18
# 2013-03-19
# 2013-03-20
# 2013-03-21
# 2013-03-22
# 2013-03-25
# 2013-03-26
# 2013-03-27
# 2013-03-28
# 2013-03-29
# 2013-04-01
# 2013-04-02
# 2013-04-03
# 2013-04-08
# 2013-04-09
# 2013-04-10
# 2013-04-11
# 2013-04-12
# 2013-04-15
# 2013-04-16
# 2013-04-17
# 2013-04-18
# 2013-04-19
# 2013-04-22
# 2013-04-23
# 2013-04-24
# 2013-04-25
# 2013-04-26
# 2013-05-02
# 2013-05-03
# ...
